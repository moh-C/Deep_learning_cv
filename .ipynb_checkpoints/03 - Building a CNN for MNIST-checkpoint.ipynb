# %%
from keras.datasets import mnist
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
import keras
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %% [markdown]
# # Loading the data

# %%
(x_train, y_train), (x_test, y_test)  = mnist.load_data()
print(x_train.shape, x_test.shape, y_test.shape, y_train.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28) (10000,) (60000,)

# %%
for i in range(0,6):
    rand = np.random.randint(0, len(x_train))
    img = x_train[rand]
    cv2.imshow('Image ' + str(i), img)
    cv2.waitKey()

cv2.destroyAllWindows()

# %%
plt.figure(figsize=(10,13))
plt.subplot(321)
rand = np.random.randint(0, len(x_train))
img = x_train[rand]
img = cv2.resize(img, None, fx=2, fy=2)
plt.imshow(img)

plt.subplot(322)
rand = np.random.randint(0, len(x_train))
img = x_train[rand]
img = cv2.resize(img, None, fx=2, fy=2)
plt.imshow(img)

plt.subplot(323)
rand = np.random.randint(0, len(x_train))
img = x_train[rand]
img = cv2.resize(img, None, fx=2, fy=2)
plt.imshow(img)

plt.subplot(324)
rand = np.random.randint(0, len(x_train))
img = x_train[rand]
img = cv2.resize(img, None, fx=2, fy=2)
plt.imshow(img)

plt.subplot(325)
rand = np.random.randint(0, len(x_train))
img = x_train[rand]
img = cv2.resize(img, None, fx=2, fy=2)
plt.imshow(img)

plt.subplot(326)
rand = np.random.randint(0, len(x_train))
img = x_train[rand]
img = cv2.resize(img, None, fx=2, fy=2)
plt.imshow(img)

plt.show()

# %%
img_rows = x_train[0].shape[0]
img_cols = x_train[0].shape[1]
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255
x_test /= 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## One-Hot Encoding Our Model

# %%
from keras.utils import np_utils

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

print ("Number of Classes: " + str(y_test.shape[1]))

num_classes = y_test.shape[1]
num_pixels = x_train.shape[1] * x_train.shape[2]
# Out:
# Number of Classes: 10

# %% [markdown]
# ## Some side notes:
# https://medium.com/@amarbudhiraja/https-medium-com-amarbudhiraja-learning-less-to-learn-better-dropout-in-deep-machine-learning-74334da4bfc5
#
# https://machinelearningmastery.com/dropout-for-regularizing-deep-neural-networks/
#
# https://www.datascience.us/neural-net-dropout-dealing-overfitting/

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = SGD(0.01),
              metrics = ['accuracy'])

# %%
model = keras.models.Sequential()

model.add(Conv2D(filters = 64, 
                 kernel_size = (3,3),
                 activation = 'relu', 
                 input_shape = input_shape))
model.add(Conv2D(filters = 64,
                kernel_size = (3,3),
                activation = 'relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=512))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss = 'categorical_crossentropy',
             optimizer = SGD(),
             metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 26, 26, 64)        640
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 9216)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               1179776
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,288,522
# Trainable params: 1,288,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
batch_size = 32
epochs = 2

history = model.fit(x = x_train,
                   y = y_train,
                   epochs = epochs,
                   batch_size = batch_size,
                   verbose = 1,
                   validation_data = (x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/2
# 60000/60000 [==============================] - 379s 6ms/step - loss: 0.7067 - accuracy: 0.7697 - val_loss: 0.2125 - val_accuracy: 0.9388
# Epoch 2/2
# 60000/60000 [==============================] - 382s 6ms/step - loss: 0.2987 - accuracy: 0.9098 - val_loss: 0.1307 - val_accuracy: 0.9610
# Test loss: 0.13073609562069177
# Test accuracy: 0.9610000252723694

# %%
model.save('First_CNN_trained_2_Epoch.h5')
print("Model Saved")
# Out:
# Model Saved
